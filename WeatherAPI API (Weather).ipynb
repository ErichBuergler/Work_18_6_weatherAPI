# %% [markdown]
# # WeatherAPI (Weather)
#
# Answer the following questions using [WeatherAPI](http://www.weatherapi.com/). I've added three cells for most questions but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# Be sure to take advantage of both the documentation and the API Explorer!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*
# - *Tip: Remember you only need to import requests once!*

# %%
import requests

# %% [markdown]
# ## 1) Make a request to the Weather API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %% [markdown]
# ## Always when starting with a API
#
# 1. find the right url or Endpoint in the Documentaion
# url_weather = ("http://api.weatherapi.com/v1/current.json?key=33defd25fc5e41caa5c184318221506&q=Sydney")
#
#
#
# 2. Always this:
# response = requests.get(url_weather)    #url_weather i can choose a name for that
# 3. data = response.json()  #i can choose a name for data
#
# Documentation in this case is

# %%
url_weather = ("http://api.weatherapi.com/v1/current.json?key=33defd25fc5e41caa5c184318221506&q=Sydney")
response = requests.get(url_weather)
data = response.json()

# %%
print(data)
# Out:
# {'location': {'name': 'Sydney', 'region': 'New South Wales', 'country': 'Australia', 'lat': -33.88, 'lon': 151.22, 'tz_id': 'Australia/Sydney', 'localtime_epoch': 1655484427, 'localtime': '2022-06-18 2:47'}, 'current': {'last_updated_epoch': 1655483400, 'last_updated': '2022-06-18 02:30', 'temp_c': 11.0, 'temp_f': 51.8, 'is_day': 0, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png', 'code': 1009}, 'wind_mph': 11.9, 'wind_kph': 19.1, 'wind_degree': 250, 'wind_dir': 'WSW', 'pressure_mb': 1022.0, 'pressure_in': 30.18, 'precip_mm': 1.0, 'precip_in': 0.04, 'humidity': 82, 'cloud': 75, 'feelslike_c': 7.9, 'feelslike_f': 46.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 26.2, 'gust_kph': 42.1}}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
data.keys()
# Out:
# dict_keys(['location', 'current'])

# %%
data.keys()
# Out:
# dict_keys(['location', 'current'])

# %%
data["current"]
# Out:
# {'last_updated_epoch': 1655483400,
#  'last_updated': '2022-06-18 02:30',
#  'temp_c': 11.0,
#  'temp_f': 51.8,
#  'is_day': 0,
#  'condition': {'text': 'Overcast',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#   'code': 1009},
#  'wind_mph': 11.9,
#  'wind_kph': 19.1,
#  'wind_degree': 250,
#  'wind_dir': 'WSW',
#  'pressure_mb': 1022.0,
#  'pressure_in': 30.18,
#  'precip_mm': 1.0,
#  'precip_in': 0.04,
#  'humidity': 82,
#  'cloud': 75,
#  'feelslike_c': 7.9,
#  'feelslike_f': 46.3,
#  'vis_km': 10.0,
#  'vis_miles': 6.0,
#  'uv': 1.0,
#  'gust_mph': 26.2,
#  'gust_kph': 42.1}

# %%
wind_speed = data["current"]['wind_kph'] #will show me the current wind speed
print("the wind speed is", wind_speed)
# Out:
# the wind speed is 19.1

# %%
data["current"]
difference = data['current']['feelslike_c']-data['current']['temp_c']
print("it feels", round(difference,2), "warmer than it acutally is")
# Out:
# it feels -3.1 warmer than it acutally is

# %% [markdown]
# ## 3) What is the API endpoint for moon-related information? For the place you decided on above, how much of the moon will be visible tomorrow?
#
# - *Tip: Check the documentation!*
# - *Tip: If you aren't sure what something means, ask in Slack*

# %% [markdown]
# ###  i found in the documentaion where the moon related info should be
# http://api.weatherapi.com/v1/forecast.json?key=33defd25fc5e41caa5c184318221506 &q=Sydney&days=1&aqi=no&alerts=no
# ### Endpoint is a link

# %%
#moon related information

url_moon = ("http://api.weatherapi.com/v1/forecast.json?key=33defd25fc5e41caa5c184318221506 &q=Sydney&days=1&aqi=no&alerts=no")
response = requests.get(url_moon)
data_moon = response.json()

print(data_moon)
# Out:
# {'location': {'name': 'Sydney', 'region': 'New South Wales', 'country': 'Australia', 'lat': -33.88, 'lon': 151.22, 'tz_id': 'Australia/Sydney', 'localtime_epoch': 1655484454, 'localtime': '2022-06-18 2:47'}, 'current': {'last_updated_epoch': 1655484300, 'last_updated': '2022-06-18 02:45', 'temp_c': 11.0, 'temp_f': 51.8, 'is_day': 0, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png', 'code': 1009}, 'wind_mph': 13.6, 'wind_kph': 22.0, 'wind_degree': 250, 'wind_dir': 'WSW', 'pressure_mb': 1022.0, 'pressure_in': 30.18, 'precip_mm': 1.0, 'precip_in': 0.04, 'humidity': 82, 'cloud': 75, 'feelslike_c': 7.9, 'feelslike_f': 46.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 26.2, 'gust_kph': 42.1}, 'forecast': {'forecastday': [{'date': '2022-06-18', 'date_epoch': 1655510400, 'day': {'maxtemp_c': 16.6, 'maxtemp_f': 61.9, 'mintemp_c': 13.3, 'mintemp_f': 55.9, 'avgtemp_c': 15.2, 'avgtemp_f': 59.3, 'maxwind_mph': 19.0, 'maxwind_kph': 30.6, 'to
# ...

# %%
print(data_moon.keys())
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
#"moon_phase" is in "astro"

data_moon["forecast"]
# Out:
# {'forecastday': [{'date': '2022-06-18',
#    'date_epoch': 1655510400,
#    'day': {'maxtemp_c': 16.6,
#     'maxtemp_f': 61.9,
#     'mintemp_c': 13.3,
#     'mintemp_f': 55.9,
#     'avgtemp_c': 15.2,
#     'avgtemp_f': 59.3,
#     'maxwind_mph': 19.0,
#     'maxwind_kph': 30.6,
#     'totalprecip_mm': 3.3,
#     'totalprecip_in': 0.13,
#     'avgvis_km': 10.0,
#     'avgvis_miles': 6.0,
#     'avghumidity': 73.0,
#     'daily_will_it_rain': 1,
#     'daily_chance_of_rain': 97,
#     'daily_will_it_snow': 0,
#     'daily_chance_of_snow': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#      'code': 1063},
#     'uv': 2.0},
#    'astro': {'sunrise': '06:59 AM',
#     'sunset': '04:53 PM',
#     'moonrise': '09:04 PM',
#     'moonset': '10:31 AM',
#     'moon_phase': 'Waning Gibbous',
#     'moon_illumination': '63'},
#    'hour': [{'time_epoch': 1655474400,
#      'time': '2022-06-18 00:00',
# ...

# %%
data_moon["forecast"]['forecastday']
# Out:
# [{'date': '2022-06-18',
#   'date_epoch': 1655510400,
#   'day': {'maxtemp_c': 16.6,
#    'maxtemp_f': 61.9,
#    'mintemp_c': 13.3,
#    'mintemp_f': 55.9,
#    'avgtemp_c': 15.2,
#    'avgtemp_f': 59.3,
#    'maxwind_mph': 19.0,
#    'maxwind_kph': 30.6,
#    'totalprecip_mm': 3.3,
#    'totalprecip_in': 0.13,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 73.0,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': 97,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'uv': 2.0},
#   'astro': {'sunrise': '06:59 AM',
#    'sunset': '04:53 PM',
#    'moonrise': '09:04 PM',
#    'moonset': '10:31 AM',
#    'moon_phase': 'Waning Gibbous',
#    'moon_illumination': '63'},
#   'hour': [{'time_epoch': 1655474400,
#     'time': '2022-06-18 00:00',
#     'temp_c': 15.0,
#     'temp_f': 59.0,
#     'is_day': 0,
# ...

# %%
moon = data_moon["forecast"]
moon
# Out:
# {'forecastday': [{'date': '2022-06-18',
#    'date_epoch': 1655510400,
#    'day': {'maxtemp_c': 16.6,
#     'maxtemp_f': 61.9,
#     'mintemp_c': 13.3,
#     'mintemp_f': 55.9,
#     'avgtemp_c': 15.2,
#     'avgtemp_f': 59.3,
#     'maxwind_mph': 19.0,
#     'maxwind_kph': 30.6,
#     'totalprecip_mm': 3.3,
#     'totalprecip_in': 0.13,
#     'avgvis_km': 10.0,
#     'avgvis_miles': 6.0,
#     'avghumidity': 73.0,
#     'daily_will_it_rain': 1,
#     'daily_chance_of_rain': 97,
#     'daily_will_it_snow': 0,
#     'daily_chance_of_snow': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#      'code': 1063},
#     'uv': 2.0},
#    'astro': {'sunrise': '06:59 AM',
#     'sunset': '04:53 PM',
#     'moonrise': '09:04 PM',
#     'moonset': '10:31 AM',
#     'moon_phase': 'Waning Gibbous',
#     'moon_illumination': '63'},
#    'hour': [{'time_epoch': 1655474400,
#      'time': '2022-06-18 00:00',
# ...

# %%
sun = moon['forecastday']
sun2 = sun[0] #that removes the bracket
sun3 = sun2['astro']
sun3["moon_phase"]
# Out:
# 'Waning Gibbous'

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?
#
# - *Tip: When you requested moon data, you probably overwrote your variables! If so, you'll need to make a new request.*

# %%
(data_moon.keys())
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
sun2
temperature = sun2['day']
difference = temperature['maxtemp_c']-temperature['mintemp_c']
print("the difference between the high and low temparatures is", round(difference,2), "Cellsius")
# Out:
# the difference between the high and low temparatures is 3.3 Cellsius

# %% [markdown]
# ## 4.5) How can you avoid the "oh no I don't have the data any more because I made another request" problem in the future?
#
# What variable(s) do you have to rename, and what would you rename them?

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next three days' worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %% [markdown]
# ## it's in Forecast. Describtion number of days

# %%
url_days = ("http://api.weatherapi.com/v1/forecast.json?key=33defd25fc5e41caa5c184318221506 &q=Sydney&days=3&aqi=no&alerts=no")
response = requests.get(url_days)
data_days = response.json()

#print(data_days)
# data_days.keys()
# data_days['forecast']['forecastday'][0]['day']

#dict_keys(['maxtemp_c', 'maxtemp_f', 'mintemp_c', 'mintemp_f',
#'avgtemp_c', 'avgtemp_f', 'maxwind_mph', 'maxwind_kph', 'totalprecip_mm', 'totalprecip_in', 'avgvis_km', 'avgvis_miles', 'avghumidity', 'daily_will_it_rain', 'daily_chance_of_rain', 'daily_will_it_snow', 'daily_chance_of_snow', 'condition', 'uv'])

# forecast_day = data_days['forecast']['forecastday'][0]['day']
#This is the forecast for day 1
#dict_keys(['maxtemp_c', 'maxtemp_f', 'mintemp_c', 'mintemp_f', 'avgtemp_c', 'avgtemp_f', 'maxwind_mph', 'maxwind_kph', 'totalprecip_mm', 'totalprecip_in', 'avgvis_km', 'avgvis_miles', 'avghumidity', 'daily_will_it_rain', 'daily_chance_of_rain', 'daily_will_it_snow', 'daily_chance_of_snow', 'condition', 'uv'])

for forecast in data_days["forecast"]["forecastday"]:
    print(forecast['date'])
    print(forecast['day']['maxtemp_f'])    
    if forecast['day']['maxtemp_f'] < 80:
        print("it is not a warm day")
    else:
        print("it is a warm day")
# Out:
# 2022-06-18
# 61.9
# it is not a warm day
# 2022-06-19
# 62.1
# it is not a warm day
# 2022-06-20
# 62.1
# it is not a warm day

# %% [markdown]
# ## 5b) The question above used to be an entire week, but not any more. Try to re-use the code above to print out seven days.
#
# What happens? Can you figure out why it doesn't work?
#
# * *Tip: it has to do with the reason you're using an API key - maybe take a look at the "Air Quality Data" introduction for a hint? If you can't figure it out right now, no worries.*

# %% [markdown]
# ## 6) What will be the hottest day in the next three days? What is the high temperature on that day?

# %%
for forecast in data_days["forecast"]["forecastday"]:
    print(forecast['date'])
    print(forecast['day']['maxtemp_f'])    

   #i did not find out how to comparre those outputs
# Out:
# 2022-06-18
# 61.9
# 2022-06-19
# 62.1
# 2022-06-20
# 62.1

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
# - *Tip: You'll only need one day of forecast*

# %% [markdown]
# ### forecastday -> hour	hour element contains hour by hour weather forecast information

# %% [markdown]
# ###  sun = moon['forecastday']
# sun2 = sun[0] #that removes the bracket
# sun3 = sun2['astro']
# sun3["moon_phase"]

# %%
url_miami = ("http://api.weatherapi.com/v1/forecast.json?key=33defd25fc5e41caa5c184318221506&q=Miami&days=1&aqi=no&alerts=no")
response = requests.get(url_miami)
data_miami = response.json()
#print(data_miami)
#data_miami.keys()
#data_miami['forecast']['forecastday'][0]['hour'][1]
#this shows me the forecast for the first hour time' and 'temp_c'
#so i will have to loop through this:

data_miami2 = data_miami['forecast']['forecastday']
data_miami3 = data_miami2[0]['hour']
#print(data_miami3)

#here i that 'time' and "temp-c" are in a List on postion 

#now i wanna remove the lsit:

data_miami4 = data_miami2[0] #I jsut choose 0 to make it into a dictionary

#print(data_miami4)

data_miami5 = data_miami4['hour']
#print(data_miami5)

#the above shows me a List with 'time' for every hour and 'temp_c' for every hour

#that works!!!!!!!!!!!!! but I must at the cloud thing
# for hours in data_miami5:
#     print('-----------')   
#     print(hours['time'])
#     print(hours['temp_f'])

#QUESTION: WHY DOES THAT NOT WORK ??????????????????????????   
# for hours in data_miami5:
#     print('-----------')   
#     print(hours['time']['temp_'])
   
for hours in data_miami5:
    print('-----------')   
    print(hours['time'])
    if hours['cloud'] > 50:
        print(hours['temp_f'], "and cloudy")
    else:
        print(hours['temp_f'])
# Out:
# -----------
# 2022-06-17 00:00
# 83.8 and cloudy
# -----------
# 2022-06-17 01:00
# 83.7 and cloudy
# -----------
# 2022-06-17 02:00
# 83.5 and cloudy
# -----------
# 2022-06-17 03:00
# 82.8 and cloudy
# -----------
# 2022-06-17 04:00
# 82.0 and cloudy
# -----------
# 2022-06-17 05:00
# 81.3 and cloudy
# -----------
# 2022-06-17 06:00
# 81.1 and cloudy
# -----------
# 2022-06-17 07:00
# 81.9 and cloudy
# -----------
# 2022-06-17 08:00
# 82.6 and cloudy
# -----------
# 2022-06-17 09:00
# 82.9
# -----------
# 2022-06-17 10:00
# 84.0
# -----------
# 2022-06-17 11:00
# 90.3
# -----------
# 2022-06-17 12:00
# 91.0
# -----------
# 2022-06-17 13:00
# 91.0
# -----------
# 2022-06-17 14:00
# 90.9
# -----------
# 2022-06-17 15:00
# 86.7
# -----------
# 2022-06-17 16:00
# 86.2 and cloudy
# -----------
# 2022-06-17 17:00
# 85.8 and cloudy
# -----------
# 2022-06-17 18:00
# 85.1
# -----------
# 2022-06-17 19:00
# 84.4
# -----------
# 2022-06-17 20:00
# 83.7 and cloudy
# -----------
# ...

# %% [markdown]
# ## 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %% [markdown]
# ## example from spotify:
# total_tracks = 0
# explicit_tracks = 0
# for track in tracks:
#     print("-------")
#     print(track['explicit'])
#     total_tracks = total_tracks + 1
#     if(track['explicit']):
#         explicit_tracks = explicit_tracks + 1
#         print("This trakc is explicit")
# percentage_explicit = explicit_tracks / total_tracks * 100
# print("total", total_tracks, "explcit", explicit_tracks, "percentage", percentage_explicit)

# %%
total_hours = 0
total_warmhours = 0
for hours in data_miami5:
#     print('-----------')
#     print(hours['temp_f'])
    total_hours = total_hours + 1
    if hours['temp_f'] > 85:
        total_warmhours = total_warmhours + 1
        #print(hours['temp_f'])
percentage_warmhours = round((100 / total_hours * total_warmhours), 2)  
print("the percentage of hours the temperature is above 85 is", percentage_warmhours)
# Out:
# the percentage of hours the temperature is above 85 is 33.33

# %% [markdown]
# ## 9) How much will it cost if you need to use 1,500,000 API calls?
#
# You are only allowed 1,000,000 API calls each month. If you were really bad at this homework or made some awful loops, WeatherAPI might shut down your free access.
#
# * *Tip: this involves looking somewhere that isn't the normal documentation.*

# %% [markdown]
# ## 10) You're too poor to spend more money! What else could you do instead of give them money?
#
# * *Tip: I'm not endorsing being sneaky, but newsrooms and students are both generally poverty-stricken.*

# %%
#sign up with another email: possibly the one from yahoo mails
